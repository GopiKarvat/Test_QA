# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\Gopi Karvat\Downloads\new_json_2 ..csv")

# %%
data
# Out:
#    page1__last_name page1__first_name  page1__dob page1__gender  \
# 0             suraj             singh  2020-06-02          Male
# 1               NaN               NaN         NaN           NaN
# 2               NaN               NaN         NaN           NaN
# 3               NaN               NaN         NaN           NaN
# 4               NaN               NaN         NaN           NaN
# 5               NaN               NaN         NaN           NaN
# 6               NaN               NaN         NaN           NaN
# 7               NaN               NaN         NaN           NaN
# 8               NaN               NaN         NaN           NaN
# 9               NaN               NaN         NaN           NaN
# 10              NaN               NaN         NaN           NaN
# 11              NaN               NaN         NaN           NaN
# 12              NaN               NaN         NaN           NaN
#
# ...

# %%
data.loc[data['page1__emailaddress'] == '@' , 'flag'] = 'True' 
data.loc[data['page1__emailaddress'] != '@', 'flag'] = 'False'

# %%
data
# Out:
#    page1__last_name page1__first_name  page1__dob page1__gender  \
# 0             suraj             singh  2020-06-02          Male
# 1               NaN               NaN         NaN           NaN
# 2               NaN               NaN         NaN           NaN
# 3               NaN               NaN         NaN           NaN
# 4               NaN               NaN         NaN           NaN
# 5               NaN               NaN         NaN           NaN
# 6               NaN               NaN         NaN           NaN
# 7               NaN               NaN         NaN           NaN
# 8               NaN               NaN         NaN           NaN
# 9               NaN               NaN         NaN           NaN
# 10              NaN               NaN         NaN           NaN
# 11              NaN               NaN         NaN           NaN
# 12              NaN               NaN         NaN           NaN
#
# ...

# %%
data['company'] = 'Fugetron Corp'

# %%
data
# Out:
#    page1__last_name page1__first_name  page1__dob page1__gender  \
# 0             suraj             singh  2020-06-02          Male
# 1               NaN               NaN         NaN           NaN
# 2               NaN               NaN         NaN           NaN
# 3               NaN               NaN         NaN           NaN
# 4               NaN               NaN         NaN           NaN
# 5               NaN               NaN         NaN           NaN
# 6               NaN               NaN         NaN           NaN
# 7               NaN               NaN         NaN           NaN
# 8               NaN               NaN         NaN           NaN
# 9               NaN               NaN         NaN           NaN
# 10              NaN               NaN         NaN           NaN
# 11              NaN               NaN         NaN           NaN
# 12              NaN               NaN         NaN           NaN
#
# ...
